# %%
# Load dataset
import pandas as pd
import numpy as np
# %matplotlib inline
df = pd.read_csv('winequality_edited.csv', delimiter = ',')

# %%
#df = pd.DataFrame({'a': np.random.randint() + 1, 'b': np.random.randn(1000),
#'c': np.random.randn(1000) - 1}, columns=['', '', ''])
df.hist()
#import matplotlib
#import matplotlib.pyplot as plt

#matplotlib.style.use('ggplot')

#df = pd.DataFrame(np.random.randint(0,10,(20,4)),columns=list('abcd'))

#df.hist(alpha=0.5, figsize=(16, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x107fb1e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x102a051d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10375f630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x103797630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1037beda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1037bedd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1085f42b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10862a7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108635438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10868eda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1086c5e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1086ff2b0>]], dtype=object)

# %% [markdown]
# #df.plot.scatter(x = 'quality', y = 'volatile_acidity')

# %% [markdown]
# #df.plot.scatter(x= 'quality', y = 'residual_sugar')

# %%
df.plot.scatter(x= 'quality', y ='pH')

# %%
df.plot.scatter(x= 'quality', y ='alcohol')
